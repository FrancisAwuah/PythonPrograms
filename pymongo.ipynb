# %%
from pymongo import MongoClient
client = MongoClient(host="localhost", port=27017)
(list(client.list_databases()))
# Out:
# ---------------------------------------------------------------------------
# ServerSelectionTimeoutError               Traceback (most recent call last)
# Untitled-2.ipynb Cell 1 in <cell line: 3>()
#       <a href='vscode-notebook-cell:Untitled-2.ipynb?jupyter-notebook#W0sdW50aXRsZWQ%3D?line=0'>1</a> from pymongo import MongoClient
#       <a href='vscode-notebook-cell:Untitled-2.ipynb?jupyter-notebook#W0sdW50aXRsZWQ%3D?line=1'>2</a> client = MongoClient(host="localhost", port=27017)
# ----> <a href='vscode-notebook-cell:Untitled-2.ipynb?jupyter-notebook#W0sdW50aXRsZWQ%3D?line=2'>3</a> (list(client.list_databases()))
#
# File ~/.local/lib/python3.10/site-packages/pymongo/mongo_client.py:1840, in MongoClient.list_databases(self, session, comment, **kwargs)
#    1838     cmd["comment"] = comment
#    1839 admin = self._database_default_options("admin")
# -> 1840 res = admin._retryable_read_command(cmd, session=session)
#    1841 # listDatabases doesn't return a cursor (yet). Fake one.
#    1842 cursor = {
#    1843     "id": 0,
#    1844     "firstBatch": res["databases"],
#    1845     "ns": "admin.$cmd",
#    1846 }
#
# File ~/.local/lib/python3.10/site-packages/pymongo/database.py:849, in Database._retryable_read_command(self, command, value, check, allowable_errors, read_preference, codec_options, session, **kwargs)
#     836 def _cmd(session, server, sock_info, read_preference):
#     837     return self._command(
#     838         sock_info,
#     839         command,
#    (...)
#     846         **kwargs,
#     847     )
# --> 849 return self.__client._retryable_read(_cmd, read_preference, session)
#
# File ~/.local/lib/python3.10/site-packages/pymongo/_csot.py:105, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     103         with _TimeoutContext(timeout):
#     104             return func(self, *args, **kwargs)
# --> 105 return func(self, *args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/pymongo/mongo_client.py:1441, in MongoClient._retryable_read(self, func, read_pref, session, address, retryable)
#    1439         raise last_error
#    1440 try:
# -> 1441     server = self._select_server(read_pref, session, address=address)
#    1442     with self._socket_from_server(read_pref, server, session) as (sock_info, read_pref):
#    1443         if retrying and not retryable:
#    1444             # A retry is not possible because this server does
#    1445             # not support retryable reads, raise the last error.
#
# File ~/.local/lib/python3.10/site-packages/pymongo/mongo_client.py:1257, in MongoClient._select_server(self, server_selector, session, address)
#    1255             raise AutoReconnect("server %s:%d no longer available" % address)
#    1256     else:
# -> 1257         server = topology.select_server(server_selector)
#    1258     return server
#    1259 except PyMongoError as exc:
#    1260     # Server selection errors in a transaction are transient.
#
# File ~/.local/lib/python3.10/site-packages/pymongo/topology.py:272, in Topology.select_server(self, selector, server_selection_timeout, address)
#     270 def select_server(self, selector, server_selection_timeout=None, address=None):
#     271     """Like select_servers, but choose a random server if several match."""
# --> 272     server = self._select_server(selector, server_selection_timeout, address)
#     273     if _csot.get_timeout():
#     274         _csot.set_rtt(server.description.round_trip_time)
#
# File ~/.local/lib/python3.10/site-packages/pymongo/topology.py:261, in Topology._select_server(self, selector, server_selection_timeout, address)
#     260 def _select_server(self, selector, server_selection_timeout=None, address=None):
# --> 261     servers = self.select_servers(selector, server_selection_timeout, address)
#     262     if len(servers) == 1:
#     263         return servers[0]
#
# File ~/.local/lib/python3.10/site-packages/pymongo/topology.py:223, in Topology.select_servers(self, selector, server_selection_timeout, address)
#     220     server_timeout = server_selection_timeout
#     222 with self._lock:
# --> 223     server_descriptions = self._select_servers_loop(selector, server_timeout, address)
#     225     return [self.get_server_by_address(sd.address) for sd in server_descriptions]
#
# File ~/.local/lib/python3.10/site-packages/pymongo/topology.py:238, in Topology._select_servers_loop(self, selector, timeout, address)
#     235 while not server_descriptions:
#     236     # No suitable servers.
#     237     if timeout == 0 or now > end_time:
# --> 238         raise ServerSelectionTimeoutError(
#     239             "%s, Timeout: %ss, Topology Description: %r"
#     240             % (self._error_message(selector), timeout, self.description)
#     241         )
#     243     self._ensure_opened()
#     244     self._request_check_all()
#
# ServerSelectionTimeoutError: localhost:27017: [Errno 111] Connection refused, Timeout: 30s, Topology Description: <TopologyDescription id: 63b69a75a7058f8057f0887e, topology_type: Unknown, servers: [<ServerDescription ('localhost', 27017) server_type: Unknown, rtt: None, error=AutoReconnect('localhost:27017: [Errno 111] Connection refused')>]>

# %%
from pymongo import MongoClient
#Create Connection
client = MongoClient('10.10.10.59', 27017)
#Select the Database
database = client.students
#Alternative Declaration Method
#database = client['students']
#Get list of cillections
collection = database.list_collection_names(include_system_collections=False)
print(collection)
# Out:
# ---------------------------------------------------------------------------
# ServerSelectionTimeoutError               Traceback (most recent call last)
# Untitled-2.ipynb Cell 2 in <cell line: 9>()
#       <a href='vscode-notebook-cell:Untitled-2.ipynb?jupyter-notebook#W1sdW50aXRsZWQ%3D?line=4'>5</a> database = client.students
#       <a href='vscode-notebook-cell:Untitled-2.ipynb?jupyter-notebook#W1sdW50aXRsZWQ%3D?line=5'>6</a> #Alternative Declaration Method
#       <a href='vscode-notebook-cell:Untitled-2.ipynb?jupyter-notebook#W1sdW50aXRsZWQ%3D?line=6'>7</a> #database = client['students']
#       <a href='vscode-notebook-cell:Untitled-2.ipynb?jupyter-notebook#W1sdW50aXRsZWQ%3D?line=7'>8</a> #Get list of cillections
# ----> <a href='vscode-notebook-cell:Untitled-2.ipynb?jupyter-notebook#W1sdW50aXRsZWQ%3D?line=8'>9</a> collection = database.list_collection_names(include_system_collections=False)
#      <a href='vscode-notebook-cell:Untitled-2.ipynb?jupyter-notebook#W1sdW50aXRsZWQ%3D?line=9'>10</a> print(collection)
#
# File ~/.local/lib/python3.10/site-packages/pymongo/database.py:959, in Database.list_collection_names(self, session, filter, comment, **kwargs)
#     956     if not filter or (len(filter) == 1 and "name" in filter):
#     957         kwargs["nameOnly"] = True
# --> 959 return [result["name"] for result in self.list_collections(session=session, **kwargs)]
#
# File ~/.local/lib/python3.10/site-packages/pymongo/database.py:911, in Database.list_collections(self, session, filter, comment, **kwargs)
#     906 def _cmd(session, server, sock_info, read_preference):
#     907     return self._list_collections(
#     908         sock_info, session, read_preference=read_preference, **kwargs
#     909     )
# --> 911 return self.__client._retryable_read(_cmd, read_pref, session)
#
# File ~/.local/lib/python3.10/site-packages/pymongo/_csot.py:105, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     103         with _TimeoutContext(timeout):
#     104             return func(self, *args, **kwargs)
# --> 105 return func(self, *args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/pymongo/mongo_client.py:1441, in MongoClient._retryable_read(self, func, read_pref, session, address, retryable)
#    1439         raise last_error
#    1440 try:
# -> 1441     server = self._select_server(read_pref, session, address=address)
#    1442     with self._socket_from_server(read_pref, server, session) as (sock_info, read_pref):
#    1443         if retrying and not retryable:
#    1444             # A retry is not possible because this server does
#    1445             # not support retryable reads, raise the last error.
#
# File ~/.local/lib/python3.10/site-packages/pymongo/mongo_client.py:1257, in MongoClient._select_server(self, server_selector, session, address)
#    1255             raise AutoReconnect("server %s:%d no longer available" % address)
#    1256     else:
# -> 1257         server = topology.select_server(server_selector)
#    1258     return server
#    1259 except PyMongoError as exc:
#    1260     # Server selection errors in a transaction are transient.
#
# File ~/.local/lib/python3.10/site-packages/pymongo/topology.py:272, in Topology.select_server(self, selector, server_selection_timeout, address)
#     270 def select_server(self, selector, server_selection_timeout=None, address=None):
#     271     """Like select_servers, but choose a random server if several match."""
# --> 272     server = self._select_server(selector, server_selection_timeout, address)
#     273     if _csot.get_timeout():
#     274         _csot.set_rtt(server.description.round_trip_time)
#
# File ~/.local/lib/python3.10/site-packages/pymongo/topology.py:261, in Topology._select_server(self, selector, server_selection_timeout, address)
#     260 def _select_server(self, selector, server_selection_timeout=None, address=None):
# --> 261     servers = self.select_servers(selector, server_selection_timeout, address)
#     262     if len(servers) == 1:
#     263         return servers[0]
#
# File ~/.local/lib/python3.10/site-packages/pymongo/topology.py:223, in Topology.select_servers(self, selector, server_selection_timeout, address)
#     220     server_timeout = server_selection_timeout
#     222 with self._lock:
# --> 223     server_descriptions = self._select_servers_loop(selector, server_timeout, address)
#     225     return [self.get_server_by_address(sd.address) for sd in server_descriptions]
#
# File ~/.local/lib/python3.10/site-packages/pymongo/topology.py:238, in Topology._select_servers_loop(self, selector, timeout, address)
#     235 while not server_descriptions:
#     236     # No suitable servers.
#     237     if timeout == 0 or now > end_time:
# --> 238         raise ServerSelectionTimeoutError(
#     239             "%s, Timeout: %ss, Topology Description: %r"
#     240             % (self._error_message(selector), timeout, self.description)
#     241         )
#     243     self._ensure_opened()
#     244     self._request_check_all()
#
# ServerSelectionTimeoutError: 10.10.10.59:27017: timed out, Timeout: 30s, Topology Description: <TopologyDescription id: 63b69d68a7058f8057f0887f, topology_type: Unknown, servers: [<ServerDescription ('10.10.10.59', 27017) server_type: Unknown, rtt: None, error=NetworkTimeout('10.10.10.59:27017: timed out')>]>
